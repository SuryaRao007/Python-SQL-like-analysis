# %%
import pandas as pd
import numpy as np
# Question Number	Company background	Details	Points (Total 23)

filepath = "C:\\Users\\jyoth\\Documents\\prashant\\Python Scripts\\DataFrame Application\\ZS.csv"
zs = pd.read_csv(filepath)
#zs.head()
# SQL Query Select Question Number, Company background,Details,Points (Total 23) from zs LIMIT 5; 
#zs[['Question Number','Company background','Details','Points (Total 23)']].head(5)
#zs.assign(Points = zs['Points (Total 23)'].notna()).head(5)
#Filter the rows with blank in Points(total 23) column
#zs[zs['Points (Total 23)'].notna()]
#Unfortunately there are some rows with zero in them
#Filter the rows with value 1 in Points(total 23) column
zs[(zs['Points (Total 23)']==1) | (zs['Points (Total 23)']==0.5) | (zs['Points (Total 23)']==2) ]
# Out:
#     Question Number                                 Company background  \
# 0               1.0  Business Model (Is it a Disruptor   | Branding...
# 1               2.0  Company moat: patents | technology |difficult ...
# 2               3.0  CEO/Founder: well known executive/famous for l...
# 3               4.0  If the company is not USA based then USA based...
# 7               7.0  Usage - Frequency : [check among investment gr...
# 9               8.0           Growth : previous 2 years & current year
# 10              9.0                              Growth : Next 2 years
# 11             10.0                                    earnings growth
# 12             11.0  If company (> 10 years old and > 1000 employee...
# 13             12.0  International Opportunities/Ease of replicatio...
# 15             13.0  Expert Opinion : Example:  Enteprise software:...
# 20             17.0                   Founder(s)/CEO : min 10% stake ?
# 21             18.0           % held by Institution and Insiders > 70%
# 22             19.0  Stock Price phase in conjunction with cell A27...
# 23             20.0                    Short Interest less than 15% ?
#
#                                               Details  Points (Total 23)  \
# 0                                     Values: 0 or 1                 0.5
# 1                                 3 values: 0,.5 or 1                0.5
# 2                                       values 0 or 1                1.0
# 3   If USA based and 3 well known  Board members t...                0.5
# 7                                                 NaN                1.0
# 9                        40%> 1, 30-40% - .5, <30% -0                1.0
# 10                       40%> 1, 20-40% - .5, <20% -0                0.5
# 11                       40%> 1, 30-40% - .5, <30% -0                0.5
# 12                                                NaN                0.5
# 13  If revenue % from the USA >70%  then give 1 if...                0.5
# 15  If the company/product rated as Top then give ...                0.5
# 20    More than 10% stake then give 1 point ,  else 0                1.0
# 21  More than 70% then 1,if between 50-70% then .5...                0.5
# 22          If A then 2 and if B then 1, If C then .5                2.0
# 23  if less than 3% then 1, if between 3 and 15 th...                0.5
#
#     Group Ranking Ideal Scenario for this stock  \
# 0             NaN                           NaN
# 1             NaN                           NaN
# 2             NaN                           NaN
# 3             NaN                           NaN
# 7             NaN                           NaN
# 9             NaN                           NaN
# 10            NaN                           NaN
# 11            NaN                           NaN
# 12            NaN                           NaN
# 13            NaN                           NaN
# 15            NaN                           NaN
# 20            1.0                           NaN
# 21            0.5                           NaN
# 22            2.0                           NaN
# 23            0.5                           NaN
#
#                                    Reference/Examples Unnamed: 7
# 0   Zscaler, Inc. operates as a cloud security com...        NaN
# 1                                                 NaN        NaN
# 2   Jay Chaudhry CEO, Chairman and Founder leverag...        NaN
# 3   https://www.crunchbase.com/\n\n10-Q (Quaterly ...        NaN
# 7   dont know personally as I am not in the tech s...        NaN
# 9   Rev growth vs prior year: 57%('17) , 51%('18),...        NaN
# 10  BBG projects 29% and 26% in the next two years...        NaN
# 11  BBG projection EPS growth: -33% for 2020 and +...        NaN
# 12  Started in 2008, Revenues < 500M & employees a...        NaN
# 13  US 51%, EMEA 40%, APAC 9 % - https://ir.zscale...        NaN
# 15  https://www.zscaler.com/gartner-magic-quadrant...        NaN
# 20                        10% ownership per fintel.io        NaN
# 21                   44 % institutional + 10% insider        NaN
# 22                                                NaN        NaN
# 23              Short interest % of free float 13.86%        NaN
